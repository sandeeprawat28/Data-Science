# %%
# importing the dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load the iris dataset
iris = pd.read_csv('/content/iris.csv')
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Plotting the data[link text](https:// [link text](https:// [link text](https:// [link text](https://))))

# %%
# Sepal Length vs Sepal  Width

plot = iris[iris.species=='Iris-setosa'].plot.scatter(x='sepal_length',y='sepal_width',color='g',label='Iris Setosa')
iris[iris.species=='Iris-versicolor'].plot.scatter(x='sepal_length',y='sepal_width',color='r',label='Iris Versicolor',ax=plot)
iris[iris.species=='Iris-virginica'].plot.scatter(x='sepal_length',y='sepal_width',color='y',label='Iris Virginica',ax=plot)

plt.title('Sepal Length Vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
# Petal Length Vs Petal Width

plot = iris[iris.species=='Iris-setosa'].plot.scatter(x='petal_length',y='petal_width',color='g',label='Iris Setosa')
iris[iris.species=='Iris-versicolor'].plot.scatter(x='petal_length',y='petal_width',color='r',label='Iris Versicolor',ax=plot)
iris[iris.species=='Iris-virginica'].plot.scatter(x='petal_length',y='petal_width',color='y',label='Iris Virginica',ax=plot)

plt.title('Petal Length Vs Petal Width')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
# Sepal Length Vs Petal Length

plot = iris[iris.species=='Iris-setosa'].plot.scatter(x='sepal_length',y='petal_length',color='g',label='Iris Setosa')
iris[iris.species=='Iris-versicolor'].plot.scatter(x='sepal_length',y='petal_length',color='r',label='Iris Versicolor',ax=plot)
iris[iris.species=='Iris-virginica'].plot.scatter(x='sepal_length',y='petal_length',color='y',label='Iris Virginica',ax=plot)

plt.title('Sepal Length Vs Petal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.show()

# %%
# Sepal Width Vs Petal Width

plot = iris[iris.species=='Iris-setosa'].plot.scatter(x='sepal_width',y='petal_width',color='g',label='Iris Setosa')
iris[iris.species=='Iris-versicolor'].plot.scatter(x='sepal_width',y='petal_width',color='r',label='Iris Versicolor',ax=plot)
iris[iris.species=='Iris-virginica'].plot.scatter(x='sepal_width',y='petal_width',color='y',label='Iris Virginica',ax=plot)

plt.title('Sepal Width Vs Petal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.show()

# %%
# Sepal Length Vs Petal Width

plot = iris[iris.species=='Iris-setosa'].plot.scatter(x='sepal_length',y='petal_width',color='g',label='Iris Setosa')
iris[iris.species=='Iris-versicolor'].plot.scatter(x='sepal_length',y='petal_width',color='r',label='Iris Versicolor',ax=plot)
iris[iris.species=='Iris-virginica'].plot.scatter(x='sepal_length',y='petal_width',color='y',label='Iris Virginica',ax=plot)

plt.title('Sepal Length Vs Petal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Width')
plt.show()
